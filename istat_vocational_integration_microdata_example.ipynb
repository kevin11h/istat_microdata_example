# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import Series, DataFrame
from IPython.core.display import Image

# %matplotlib inline
pd.options.display.mpl_style = 'default'

print pd.__version__
# Out:
# 0.15.1

# %%
data_dir = '~/Desktop/InsProLau_2011_IT/MICRODATI/'
# !ls $data_dir
# Out:
# InsProLau_Microdati_Anno_2011.csv
# InsProLau_Microdati_Anno_2011_translated_english.csv
# InsProLau_Microdati_Anno_2011_translated_english_trunc.csv
# InsProLau_Microdati_Anno_2011.txt

# %%
Image('meena.png')

# %%
Image('trans_eng_trunc.png')

# %%
trans_eng_trunc_csv_filename = os.path.join(data_dir, 'InsProLau_Microdati_Anno_2011_translated_english_trunc.csv')
# !cp $trans_eng_trunc_csv_filename .

# %%
df = DataFrame.from_csv('InsProLau_Microdati_Anno_2011_translated_english_trunc.csv', sep='\t', index_col=None)
df
# Out:
#        Subject_area  Student_teaching_region    COEFFIN
# 0                 4                        1  15.164559
# 1                 4                        1  23.337043
# 2                 8                        1   1.801117
# 3                 1                        1  25.882294
# 4                 1                        1   3.365517
# 5                 1                        1   3.365517
# 6                 1                        1   3.365517
# 7                 1                        1  16.719019
# 8                 1                        1   3.365517
# 9                 1                        1  21.672363
# 10                1                        1  21.672363
# 11                1                        1  21.672363
# 12                1                        1  21.672363
# 13                1                        1  21.672363
# 14                1                        1  21.672363
# 15                1                        1  21.672363
# ...

# %% [markdown]
# What is Ordinary Least Squares (OLS) Regression? <br />
# Let's not go down that rabbit hole, just show me how to create it using code: <br />
#
# > http://stackoverflow.com/questions/19991445/run-an-ols-regression-with-pandas-data-frame <br />
#
# I'm assuming that subject area is the response variable and  teaching region is the explanatory variable.

# %%
import statsmodels.formula.api as sm

result = sm.ols(formula="Subject_area ~ Student_teaching_region", data=df).fit()
print result.params
# Out:
# Intercept                  4.809897
# Student_teaching_region    0.001871
# dtype: float64

# %%
print result.summary()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Subject_area   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.5457
# Date:                Wed, 31 Dec 2014   Prob (F-statistic):              0.460
# Time:                        05:40:23   Log-Likelihood:                -80021.
# No. Observations:               33696   AIC:                         1.600e+05
# Df Residuals:                   33694   BIC:                         1.601e+05
# Df Model:                           1
# ...
#                               coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------------------
# Intercept                   4.8099      0.029    166.884      0.000         4.753     4.866
# ...
